# %% [markdown]
# # QUESTION NO. 5
# #  ML-MINOR-APRIL
# #  Name = Om Patil
# #  Batch = Verzeo April ML

# %%
import pandas as pd

# %%
data=pd.read_csv("F:\\ml\\verzeo minor\\minor.csv",encoding=('ISO-8859-1'))

# %%
success_orders=data[(data['Order Status']=='COMPLETE') & (data['Delivery Status'] != 'Shipping canceled')]

# %% [markdown]
# THE ABOVE CONDITION WILL FILTER THE DATA ACCORDING TO CONDITION

# %%
success_orders
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       DEBIT                         3                              4
# 3       DEBIT                         3                              4
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# ...       ...                       ...                            ...
# 180500  DEBIT                         3                              4
# 180505  DEBIT                         2                              4
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
# THE BELOW CONDTION ACCORDING TO QUESTION

# %%
real_greater_scheduled=data[(data['Days for shipping (real)']) > (data['Days for shipment (scheduled)'])]

# %%
real_greater_scheduled
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 5       TRANSFER                         6                              4
# 6          DEBIT                         2                              1
# 7       TRANSFER                         2                              1
# 8           CASH                         3                              2
# ...          ...                       ...                            ...
# 180507   PAYMENT                         5                              2
# 180508     DEBIT                         4                              2
# 180512     DEBIT                         6                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
len(real_greater_scheduled)
# Out:
# 103400

# %% [markdown]
# "103400" THIS IS THE TOTAL NUMBER OF ROWS INCLUDED IN IN ORDER TO
# SUCCESSFULL ORDERS ACCORDING TO THE CONDITION
